# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\KSSEEB\OneDrive\Documents\Python certisured\EDA\Diwali\Diwali.csv",encoding = 'unicode_escape')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df.drop(columns=['User_ID', 'Status','unnamed1'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Cust_name Product_ID Gender Age Group  Age  Marital_Status           State  \
# 0  Sanskriti  P00125942      F     26-35   28               0     Maharashtra
# 1     Kartik  P00110942      F     26-35   35               1  Andhra Pradesh
# 2      Bindu  P00118542      F     26-35   35               1   Uttar Pradesh
# 3     Sudevi  P00237842      M      0-17   16               0       Karnataka
# 4       Joni  P00057942      M     26-35   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
df['Amount'].fillna(df['Amount'].mean(), inplace = True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Age Group'].unique()
# Out:
# array(['26-35', '0-17', '18-25', '55+', '46-50', '51-55', '36-45'],
#       dtype=object)

# %%
df['Age Group'].replace({'0-17':'young','18-25':'adult','26-35':'adult','36-45':'middle_age','45-50':'middleage','50-55':'middleage','55+':'senior'},inplace=True)

# %%
df['Gender'].replace({"F":"Female","M":"Male"}, inplace = True)

# %%
df["Age Group"].unique()
# Out:
# array(['adult', 'young', 'senior', '46-50', '51-55', 'middle_age'],
#       dtype=object)

# %%
df.describe().T
# Out:
#                   count         mean          std    min     25%     50%  \
# Age             11243.0    35.422841    12.756369   12.0    27.0    33.0
# Marital_Status  11243.0     0.420261     0.493623    0.0     0.0     0.0
# Orders          11243.0     2.488749     1.114960    1.0     1.0     2.0
# Amount          11243.0  9454.084476  5218.941128  188.0  5444.0  8111.0
#
#                     75%      max
# Age                43.0     92.0
# Marital_Status      1.0      1.0
# Orders              3.0      4.0
# Amount          12672.0  23952.0

# %%
df.describe(include='object').T
# Out:
#                   count unique                 top  freq
# Cust_name         11243   1250            Vishakha    42
# Product_ID        11243   2351           P00265242    53
# Gender            11243      2              Female  7838
# Age Group         11243      6               adult  6416
# State             11243     16       Uttar Pradesh  1944
# Zone              11243      5             Central  4294
# Occupation        11243     15           IT Sector  1586
# Product_Category  11243     18  Clothing & Apparel  2653

# %%
Cat_col = df.select_dtypes(include=['object']).columns
num_col = df.select_dtypes(include=np.number).columns.tolist()
print(Cat_col)
print(num_col)
# Out:
# Index(['Cust_name', 'Product_ID', 'Gender', 'Age Group', 'State', 'Zone',
#        'Occupation', 'Product_Category'],
#       dtype='object')
# ['Age', 'Marital_Status', 'Orders', 'Amount']

# %%
for col in num_col:
    print(col)

    plt.figure()

    plt.subplot(1,2,1)
    sns.histplot(x=df[col], kde=True, alpha=0.5, bins=10, edgecolor='black')
    plt.ylabel('frequency')

    plt.subplot(1,2,2)
    sns.boxplot(x = df[col])

    plt.tight_layout()
    plt.show()
# Out:
# Age
# Marital_Status
# Orders
# Amount

# %%
for col in Cat_col:
    print(col)

    sns.countplot(x=df[col], order = df[col].value_counts().head(10).index, palette='Set2')
    plt.xticks(rotation=90)
    plt.title(col, fontsize = 20 , fontweight='bold')
    plt.show()
# Out:
# Cust_name
# Product_ID
# Gender
# Age Group
# State
# Zone
# Occupation
# Product_Category

# %%
df['Product_Category'].value_counts()
# Out:
# Product_Category
# Clothing & Apparel       2653
# Food                     2493
# Electronics & Gadgets    2082
# Footwear & Shoes         1064
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 353
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                       99
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
df['Product_ID'].value_counts().head(10)
# Out:
# Product_ID
# P00265242    53
# P00110942    44
# P00184942    37
# P00237542    35
# P00112142    34
# P00114942    33
# P00110742    32
# P00145042    30
# P00110842    30
# P00112542    30
# Name: count, dtype: int64

# %%
df['Product_ID'].value_counts().tail(10)
# Out:
# Product_ID
# P00272942    1
# P00027642    1
# P00134842    1
# P00031342    1
# P00273142    1
# P00060142    1
# P00267042    1
# P00147142    1
# P00317642    1
# P00296942    1
# Name: count, dtype: int64

# %%
a = df['Product_ID'].value_counts().reset_index().rename(columns={'index':'Product_ID','Product_ID':'count'})

# %%
a
# Out:
#           count  count
# 0     P00265242     53
# 1     P00110942     44
# 2     P00184942     37
# 3     P00237542     35
# 4     P00112142     34
# ...         ...    ...
# 2346  P00060142      1
# 2347  P00267042      1
# 2348  P00147142      1
# 2349  P00317642      1
# 2350  P00296942      1
#
# [2351 rows x 2 columns]

# %%
a[a["count"]==1].count()
# Out:
# count      0
# count    630
# dtype: int64

# %%
total_orders = df.groupby('Product_ID')["Orders"].sum()
total_orders.sort_values(ascending=False).head(10)
# Out:
# Product_ID
# P00265242    127
# P00110942    116
# P00237542     91
# P00184942     82
# P00114942     79
# P00025442     79
# P00117942     76
# P00145042     76
# P00044442     75
# P00110842     74
# Name: Orders, dtype: int64

# %%
cor = df[num_col].corr()
sns.heatmap(cor, annot=True, cmap='PuBu')
plt.show()

# %%
zone_orders = df.groupby('Zone')["Orders"].sum().sort_values(ascending=False)
state_orders = df.groupby('State')["Orders"].sum().sort_values(ascending=False)
Product_category_orders = df.groupby('Product_Category')["Orders"].sum().sort_values(ascending=False).head()
Product_orders = df.groupby('Product_ID')["Orders"].sum().sort_values(ascending=False).head()

# %%
plt.figure(fontsize=(10,10))
plt.subplot(2,2,1)
plt.pie(zone_orders, labels=zone_orders)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plt.figure(fontsize=(10,10))
#       2 plt.subplot(2,2,1)
#       3 plt.pie(zone_orders, labels=zone_orders)
#
# File c:\Users\KSSEEB\anaconda3\Lib\site-packages\matplotlib\pyplot.py:934, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     924 if len(allnums) == max_open_warning >= 1:
#     925     _api.warn_external(
#     926         f"More than {max_open_warning} figures have been opened. "
#     927         f"Figures created through the pyplot interface "
#    (...)
#     931         f"Consider using `matplotlib.pyplot.close()`.",
#     932         RuntimeWarning)
# --> 934 manager = new_figure_manager(
#     935     num, figsize=figsize, dpi=dpi,
#     936     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
# ...

# %%
df.columns
# Out:
# Index(['Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')
